# %% [markdown]
# <a href="https://colab.research.google.com/github/sorielkobayashi/Custom-Spleeter-Colab/blob/main/Extract%20Audio%20from%20video%20%2B%20Mediainfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown <h3>← Click Here to Install FFmpeg, VCSI, Mkvtoolnix, Firefox, Furiousmount & Handbrake</h3>

#@title <font size="5">← ឵឵<i>Upgrade FFmpeg to v4.2.2</font> { vertical-output: true }
from IPython.display import clear_output
import os, urllib.request
HOME = os.path.expanduser("~")
pathDoneCMD = f'{HOME}/doneCMD.sh'
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/totalleecher/" \
                "Google-Colab-CloudTorrent/master/res/ttmg.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")

from ttmg import (
    loadingAn,
    textAn,
)

loadingAn(name="lds")
textAn("Installing Dependencies...", ty='twg')
#os.system('pip install git+git://github.com/AWConant/jikanpy.git') //GPU Not supported
#os.system('add-apt-repository -y ppa:jonathonf/ffmpeg-4') //GPU Not supported
os.system('apt-get update')
os.system('apt-get install ffmpeg')
os.system('apt-get install mkvtoolnix')
os.system('pip install vcsi')
#os.system('sudo apt-get install synaptic')
#os.system('sudo apt install firefox')
os.system('sudo add-apt-repository ppa:stebbins/handbrake-releases -y')
os.system('sudo apt update -y')
os.system('sudo apt install --install-recommends handbrake-gtk handbrake-cli')
#os.system('sudo apt-get install furiusisomount')

clear_output()
print("Install Finished")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#aqui empieza a extraer
import os, sys, re





#!ffmpeg -i -map 0:a:2 "$inputFile" -c copy s01e%1_latino.mkv



#!ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 01 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e01_castellano.m4a"
#!ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 02 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e02_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 03 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e03_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 04 [AnimeDTUP.com.mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e04_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 05 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e05_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 06 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e06_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 07 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e07_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 08 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e08_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 09 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e09_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 10 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e10_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 11 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e11_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 12 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e12_castellano.m4a"
# !ffmpeg -i "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 13 [AnimeDTUP.com].mkv"  -map 0:a:1 -c copy "/content/drive/MyDrive/TORRENTE2/ReLife AUDIO/s01e13_castellano.m4a"
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# ============================= FORM ============================= #
# @markdown <font size=5>← [Start] MediaInfo</font>
path_to_file = "/content/drive/MyDrive/TORRENTE2/ReLife/[DTUPGames] ReLIFE - 01 [AnimeDTUP.com].mkv" # @param {type:"string"}
save_output_to_file = True # @param {type:"boolean"}
# ================================================================ #

import os, uuid, re, IPython
import ipywidgets as widgets
import time
from glob import glob
from IPython.display import HTML, clear_output

def mediainfo():
  get_ipython().system_raw("""mediainfo --LogFile="/root/.nfo" "$path_to_file" """)
  with open('/root/.nfo', 'r') as file:
    media = file.read()
    media = media.replace(os.path.dirname(path_to_file)+"/", "")
  print(media)
  get_ipython().system_raw("rm -f '/root/.nfo'")
  
  if save_output_to_file:
    txt = path.rpartition('.')[0] + ".txt"
    if os.path.exists(txt):
      get_ipython().system_raw("rm -f '$txt'")
    with open(txt, 'a+') as file:
      file.write(media)
    
if not os.path.exists("/usr/bin/mediainfo"):
  get_ipython().system_raw("apt-get install mediainfo")
  
mediainfo()
# Out:
# General
# Unique ID                                : 8094243807194058530645140297842924570 (0x616E507F2FC55092335660DE27F9C1A)
# Complete name                            : [DTUPGames] ReLIFE - 01 [AnimeDTUP.com].mkv
# Format                                   : Matroska
# Format version                           : Version 4 / Version 2
# File size                                : 357 MiB
# Duration                                 : 23 min 42 s
# Overall bit rate                         : 2 106 kb/s
# Movie name                               : By DTUP Games | AnimeDTUP.com
# Encoded date                             : UTC 2019-11-04 18:22:24
# Writing application                      : mkvmerge v34.0.0 ('Sight and Seen') 64-bit
# Writing library                          : libebml v1.3.7 + libmatroska v1.5.0
# ...
